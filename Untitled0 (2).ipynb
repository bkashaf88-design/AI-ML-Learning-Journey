# %% [markdown]
# Problem: Create variables to store your favorite movie title (str), release year (int), IMDb rating (float), and whether you have watched it (bool). Print each on a new line.

# %%
movie_title="the aunt bull"
release_year = 2020
rating = 8.8
watched = True

print(movie_title)
print(release_year)
print(rating)
print(watched)
# Out:
# Ek thi nigar
# 2020
# 8.8
# True

# %% [markdown]
# Question 2: Checking Data Types
# Problem: Define three variables: a = 42, b = 3.14159, and c = "AI/ML". Use the type() function to print the data type of each variable.

# %%
a=42
b=3.14159
c="Ai/ML"

print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# Problem: Store a product name "Laptop", price 850.50, and quantity 2 in variables. Print a sentence using an f-string: "I bought 2 Laptops for $850.5 each."

# %%
p_name = "laptop"
quantity = 2
price = 256.2

print(f"i bought {quantity} {p_name}s for ${price} each")
# Out:
# i bought 2 laptops for $256.2 each

# %% [markdown]
# Question 4: String-to-Integer Conversion
# Problem: You receive a user input stored as a string: str_age = "20". Convert this string into an integer, add 5 years to it, and print the new age.

# %%
str_age =20
int_age =int(str_age)
future_age = int_age + 5

print(f"the future age will be after 5 years is {future_age}")
# Out:
# the future age will be after 5 years is 25

# %% [markdown]
# Question 5: Float-to-Integer Truncation
# Problem: Store a GPA score of 3.85 in a variable gpa. Convert it to an integer using int() and print both the original float and converted integer to see what happens.

# %%
Gpa = 3.85
int_gpa = int(Gpa)

print(f"original gpa:{Gpa} ")
print(f"Truncated gpa:{int_gpa}")
# Out:
# original gpa:3.85
# Truncated gpa:3

# %% [markdown]
# Problem: Define two variables: study_hours = 30 and required_hours = 25. Create a boolean variable has_passed_target that checks if study_hours is greater than or equal to required_hours. Print the result.

# %%
study_hours = 30
required_hours = 25
has_passed_target = study_hours >= required_hours
print(f"Target achieved { has_passed_target}")
# Out:
# Target achieved True

# %% [markdown]
# Problem: Create two variables: x = "10" and y = "20". Print the result of x + y. Then convert both to integers and print the result of int(x) + int(y).

# %%
x = 10
y = 20

print(f"print original value {x + y}")
print(f"integer value {int(x) + int(y)}")
# Out:
# print original value 30
# integer value 30
